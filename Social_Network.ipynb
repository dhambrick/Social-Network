# %% [markdown]
# <a href="https://colab.research.google.com/github/dhambrick/Social-Network/blob/master/Social_Network.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import networkx as nx 
import matplotlib.pyplot as plt

# %% [markdown]
# #Barabasi Albert Graphs
# The Barabási–Albert (BA) model is an algorithm for generating random scale-free networks using a preferential attachment mechanism. Several natural and human-made systems, including the Internet, the world wide web, citation networks, and some social networks are thought to be approximately scale-free and certainly contain few nodes (called hubs) with unusually high degree as compared to the other nodes of the network. The BA model tries to explain the existence of such nodes in real networks. The algorithm is named for its inventors Albert-László Barabási and Réka Albert and is a special case of an earlier and more general model called Price's model.
# ##Generating  Barabasi-Albert graphs in networx
# NetworkX is a Python library for studying graphs and networks. It allows researchers to construct ,analyze, and visual a wide variety of graphs and networks and their associated algorithms. As a built in functionality, Networkx allows us to generate a random babarbasi-albert graph with a couple lines of code. We demonstrate its use below.

# %%
num_nodes = 20
num_edg =  5
rand_social_net = nx.barabasi_albert_graph(num_nodes, num_edg)

# %%
nx.draw(rand_social_net)
plt.show()
